# %% [markdown]
# # Import Packages

# %%
import librosa
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  
from scipy import signal 
from scipy.io import wavfile 
import os 
import IPython.display as ipd
import math as mt 
import librosa 
from librosa.display import waveplot
import pandas as pd
import tensorflow as tf
# %matplotlib inline 
# %pylab inline
pylab.rcParams['figure.figsize'] = (18, 6)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import keras
import pydot as pyd
import pydotplus
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
keras.utils.vis_utils.pydot = pydot
import graphviz
# Out:
# Using TensorFlow backend.

# %%
model = tf.keras.models.load_model('Saved_Models/conv1d_model.h5')

# %% [markdown]
# # Visualize 1D CNN model.

# %%
# plot_model(model)
tf.keras.utils.plot_model(model,to_file='model1.png',show_shapes=True, show_layer_names=True,
    rankdir='TB', expand_nested=False, dpi=80)

# %% [markdown]
# # Visualize 2D Convolution Model.

# %%
model_2D = tf.keras.models.load_model('Saved_Models/Conv2D_model.h5')

# %%
tf.keras.utils.plot_model(model_2D,to_file='model2.png',show_shapes=True, show_layer_names=True,
    rankdir='TB', expand_nested=False, dpi=90)

# %% [markdown]
# # Visualize RNN with Attention Model.

# %%
model_RNN = tf.keras.models.load_model('Saved_Models/attRNN_model.h5')

# %%
tf.keras.utils.plot_model(model_RNN,to_file='model3.png',show_shapes=True, show_layer_names=True,
    rankdir='TB', expand_nested=False, dpi=80)
